# %% [markdown]
# ---
# - Nama              : Muhammad Afza Nur Hakim
# - Batch             : HCK-034
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input

# %%
model = load_model('marine_classification.keras')

# %% [markdown]
# # Inferencing 1

# %%
img_path = 'dolphin.jpg'

img = image.load_img(img_path, target_size=(299, 299))

plt.imshow(img)
plt.axis('off')
plt.title("Inferencing 1")
plt.show()

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# Predict
pred_probs = model.predict(img_array)
pred_class = np.argmax(pred_probs)

class_names = ['Dolphin', 'Fish', 'Lobster', 'Octopus', 'Sea Horse']

print("Prediction:", class_names[pred_class])
print("Confidence:", np.max(pred_probs))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# Prediction: Dolphin
# Confidence: 0.9999392

# %% [markdown]
# # Inferencing 2

# %%
img_path = 'fish.jpg'

img = image.load_img(img_path, target_size=(299, 299))

plt.imshow(img)
plt.axis('off')
plt.title("Inferencing 2")
plt.show()

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# Predict
pred_probs = model.predict(img_array)
pred_class = np.argmax(pred_probs)

class_names = ['Dolphin', 'Fish', 'Lobster', 'Octopus', 'Sea Horse']

print("Prediction:", class_names[pred_class])
print("Confidence:", np.max(pred_probs))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# Prediction: Fish
# Confidence: 0.9991879

# %% [markdown]
# # Inferencing 3

# %%
img_path = 'lobster.jpg'

img = image.load_img(img_path, target_size=(299, 299))

plt.imshow(img)
plt.axis('off')
plt.title("Inferencing 3")
plt.show()

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# Predict
pred_probs = model.predict(img_array)
pred_class = np.argmax(pred_probs)

class_names = ['Dolphin', 'Fish', 'Lobster', 'Octopus', 'Sea Horse']

print("Prediction:", class_names[pred_class])
print("Confidence:", np.max(pred_probs))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Prediction: Lobster
# Confidence: 0.97698146

# %% [markdown]
# # Inferencing 4

# %%
img_path = 'octopus.jpeg'

img = image.load_img(img_path, target_size=(299, 299))

plt.imshow(img)
plt.axis('off')
plt.title("Inferencing 4")
plt.show()

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# Predict
pred_probs = model.predict(img_array)
pred_class = np.argmax(pred_probs)

class_names = ['Dolphin', 'Fish', 'Lobster', 'Octopus', 'Sea Horse']

print("Prediction:", class_names[pred_class])
print("Confidence:", np.max(pred_probs))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Prediction: Octopus
# Confidence: 0.9833577

# %% [markdown]
# # Inferencing 5

# %%
img_path = 'seahorse.jpg'

img = image.load_img(img_path, target_size=(299, 299))

plt.imshow(img)
plt.axis('off')
plt.title("Inferencing 5")
plt.show()

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
# Predict
pred_probs = model.predict(img_array)
pred_class = np.argmax(pred_probs)

class_names = ['Dolphin', 'Fish', 'Lobster', 'Octopus', 'Sea Horse']

print("Prediction:", class_names[pred_class])
print("Confidence:", np.max(pred_probs))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Prediction: Sea Horse
# Confidence: 0.9826812
